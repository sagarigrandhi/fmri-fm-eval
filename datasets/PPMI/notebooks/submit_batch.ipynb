# %%
import math

from lightning_sdk import Studio, Machine, Job
import numpy as np

# %%
studio = Studio(name="connor-preprocess", teamspace="medarc", org="medarc")

# %%
num_jobs = 715
batch_size = 54
num_batches = num_jobs // batch_size

offsets = np.round(np.linspace(0, num_jobs, num_batches + 1)).astype(np.int64)
starts = offsets[:-1]
stops = offsets[1:]
batch_sizes = stops - starts
for ii, (start, stop) in enumerate(zip(starts, stops)):
    print(ii, start, stop, stop - start)
print(batch_sizes.sum())
# Out:
# 0 0 55 55
# 1 55 110 55
# 2 110 165 55
# 3 165 220 55
# 4 220 275 55
# 5 275 330 55
# 6 330 385 55
# 7 385 440 55
# 8 440 495 55
# 9 495 550 55
# 10 550 605 55
# 11 605 660 55
# 12 660 715 55
# 715

# %%
batch_ids = [0]

for batch_id in batch_ids:
    start = starts[batch_id]
    stop = stops[batch_id]
    name = f"ppmi_fmriprep_v0_{batch_id:02d}"

    job = Job.run(
        command=f"bash fmri-fm-eval/datasets/PPMI/scripts/preprocess_batch.sh {start} {stop}",
        name=name,
        machine=Machine.DATA_PREP_MAX,
        studio=studio,
        interruptible=False,
    )
    print(job.name)
# Out:
# INFO - Job was successfully launched. View it at https://lightning.ai/medarc/medarc/studios/connor-preprocess/app?app_id=jobs&job_name=ppmi-fmriprep-v0-00-bosx4
# ppmi-fmriprep-v0-00-bosx4
